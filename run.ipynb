# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

import pandas as pd
import os
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


from src.data import make_dataset
from src.features import build_features
from src.models import train_model
from src.visualization import visualize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#TODO: load data, clean, save processed data

#Loading in raw data
data_files = os.listdir('data')
datasets = {}

for file in data_files:
    path = "data\\" + file
    if (('.tsv' in file) and ('taxonomy' not in file)) : #We are not using taxonomy table for now
        df = make_dataset.read_fungi_data(path) #Read the dataset into a Pandas dataframe
        datasets[file] = df #Put the dataframe to a dictionary, with the name of the file as the key
    if '.csv' in file: #Reading the TCGA abbreviations
        df = make_dataset.read_tcga_abbrev(path)
        datasets[file] = df
#TODO Processing data and saving them in 'interim_data'


#TODO: loop for cross validation

#TODO: build models, predict, and score

#TODO: save plotting data, generate plot

#TODO: other outputs (final models, scores, etc.)
# Out:
#                                 G000001985  G000002515  G000002525  \
# sampleid
# 13722.58cfa82fe4b0c9d6adf6b62c           0           0           0
# 13722.58cfa82fe4b0c9d6adf6b5e0           0           0           0
# 13722.58cfa82ee4b0c9d6adf6af8e           1           0           0
# 13722.58cfa82ee4b0c9d6adf6af20           0           0           0
# 13722.58cfa82fe4b0c9d6adf6b669           0           0           0
# ...                                    ...         ...         ...
# 13722.58cfa832e4b0c9d6adf6ceda           0           0           0
# 13722.58cfa832e4b0c9d6adf6cedd           0           0           0
# 13722.58cfa831e4b0c9d6adf6cc9a           0           0           0
# 13722.58cfa832e4b0c9d6adf6ce50           0           0           0
# 13722.58cfa831e4b0c9d6adf6ca70           0           0           1
#
#                                 G000002545  G000002655  G000002715  \
# sampleid
# 13722.58cfa82fe4b0c9d6adf6b62c           0           1           0
# ...
